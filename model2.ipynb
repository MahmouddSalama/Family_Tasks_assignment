# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('data\Family_Tasks_Dataset.csv')
print(len(df))
df.head()
# Out:
# 100
#   Member ID  Age                                  Skills Availability  \
# 0      M001   50          ['Teaching', 'DIY', 'Cooking']   Afternoons
# 1      M002   24                     ['Cleaning', 'DIY']   Afternoons
# 2      M003   11                ['Cleaning', 'Teaching']   Afternoons
# 3      M004   51  ['Painting', 'Organizing', 'Teaching']   Afternoons
# 4      M005   47                ['Gardening', 'Cooking']     Evenings
#
#   Task Preference               Task Name  \
# 0        Physical            Fold laundry
# 1          Indoor  Vacuum the living room
# 2         Outdoor      Help with homework
# 3        Physical            Fold laundry
# 4          Indoor         Paint the fence
#
#                         Task Description Task Duration Task Difficulty  \
# 0  Prepare a chocolate cake for dessert.       2 hours            Hard
# 1               Repair the broken chair.        1 hour          Medium
# 2      Decorate the house for the party.    30 minutes            Easy
# 3              Paint the backyard fence.       3 hours            Hard
# 4       Arrange books by size and genre.        1 hour          Medium
#
#   Priority Level     Task Skills Required Assigned Status           Feedback
# 0            Low    ['DIY', 'Organizing']      Unassigned                  -
# 1           High  ['Baking', 'Gardening']      Unassigned         Great job!
# 2            Low  ['Cleaning', 'Cooking']       Completed  Fantastic effort!
# 3           High             ['Teaching']       Completed     Could improve!
# 4         Medium              ['Cooking']       Completed     Could improve!

# %%
df.isna().sum()
# Out:
# Member ID               0
# Age                     0
# Skills                  0
# Availability            0
# Task Preference         0
# Task Name               0
# Task Description        0
# Task Duration           0
# Task Difficulty         0
# Priority Level          0
# Task Skills Required    0
# Assigned Status         0
# Feedback                0
# dtype: int64

# %%
df['Feedback'].fillna('No Feedback', inplace=True)

# %%
df['Skills'] = df['Skills'].apply(ast.literal_eval)
df['Task Skills Required'] = df['Task Skills Required'].apply(ast.literal_eval)

# %%
task_preference_mapping = {'Indoor': 0, 'Outdoor': 1, 'Physical': 2, 'Creative': 3}
df['Task Preference'] = df['Task Preference'].map(task_preference_mapping)

task_difficulty_mapping = {'Easy': 0, 'Medium': 1, 'Hard': 2}
df['Task Difficulty'] = df['Task Difficulty'].map(task_difficulty_mapping)

assigned_status_mapping = {'Unassigned': 0, 'Assigned': 1, 'Completed': 2}
df['Assigned Status'] = df['Assigned Status'].map(assigned_status_mapping)

# %%
df['Age Group'] = pd.cut(df['Age'], bins=[0, 12, 19, 59, 100], labels=['Child', 'Teen', 'Adult', 'Senior'])

# %%
df.head()
# Out:
#   Member ID  Age                            Skills Availability  \
# 0      M001   50          [Teaching, DIY, Cooking]   Afternoons
# 1      M002   24                   [Cleaning, DIY]   Afternoons
# 2      M003   11              [Cleaning, Teaching]   Afternoons
# 3      M004   51  [Painting, Organizing, Teaching]   Afternoons
# 4      M005   47              [Gardening, Cooking]     Evenings
#
#    Task Preference               Task Name  \
# 0                2            Fold laundry
# 1                0  Vacuum the living room
# 2                1      Help with homework
# 3                2            Fold laundry
# 4                0         Paint the fence
#
#                         Task Description Task Duration  Task Difficulty  \
# 0  Prepare a chocolate cake for dessert.       2 hours                2
# 1               Repair the broken chair.        1 hour                1
# 2      Decorate the house for the party.    30 minutes                0
# 3              Paint the backyard fence.       3 hours                2
# 4       Arrange books by size and genre.        1 hour                1
#
#   Priority Level Task Skills Required  Assigned Status           Feedback  \
# 0            Low    [DIY, Organizing]                0                  -
# 1           High  [Baking, Gardening]                0         Great job!
# 2            Low  [Cleaning, Cooking]                2  Fantastic effort!
# 3           High           [Teaching]                2     Could improve!
# 4         Medium            [Cooking]                2     Could improve!
#
#   Age Group
# 0     Adult
# 1     Adult
# 2     Child
# 3     Adult
# 4     Adult

# %%
df['Task Duration'] = df['Task Duration'].str.extract('(\d+)').astype(float)
df.head()
# Out:
#   Member ID  Age                            Skills Availability  \
# 0      M001   50          [Teaching, DIY, Cooking]   Afternoons
# 1      M002   24                   [Cleaning, DIY]   Afternoons
# 2      M003   11              [Cleaning, Teaching]   Afternoons
# 3      M004   51  [Painting, Organizing, Teaching]   Afternoons
# 4      M005   47              [Gardening, Cooking]     Evenings
#
#    Task Preference               Task Name  \
# 0                2            Fold laundry
# 1                0  Vacuum the living room
# 2                1      Help with homework
# 3                2            Fold laundry
# 4                0         Paint the fence
#
#                         Task Description  Task Duration  Task Difficulty  \
# 0  Prepare a chocolate cake for dessert.            2.0                2
# 1               Repair the broken chair.            1.0                1
# 2      Decorate the house for the party.           30.0                0
# 3              Paint the backyard fence.            3.0                2
# 4       Arrange books by size and genre.            1.0                1
#
#   Priority Level Task Skills Required  Assigned Status           Feedback  \
# 0            Low    [DIY, Organizing]                0                  -
# 1           High  [Baking, Gardening]                0         Great job!
# 2            Low  [Cleaning, Cooking]                2  Fantastic effort!
# 3           High           [Teaching]                2     Could improve!
# 4         Medium            [Cooking]                2     Could improve!
#
#   Age Group
# 0     Adult
# 1     Adult
# 2     Child
# 3     Adult
# 4     Adult

# %%
from sklearn.preprocessing import MinMaxScaler
import joblib
scaler = MinMaxScaler()
df['Task Duration Scaled'] = scaler.fit_transform(df[['Task Duration']])
joblib.dump(scaler,'Duration_Scaled')
# Out:
# ['Duration_Scaled']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(max_features=50)
task_description_tfidf = tfidf.fit_transform(df['Task Description'])
task_description_df = pd.DataFrame(task_description_tfidf.toarray(), columns=tfidf.get_feature_names_out())
df = pd.concat([df, task_description_df], axis=1)

# %%
joblib.dump(tfidf,'tfidf')
# Out:
# ['tfidf']

# %%
from sklearn.model_selection import train_test_split
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('data\Family_Tasks_Dataset.csv')

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Task Duration'], bins=20, kde=True)
plt.title('Distribution of Task Duration')
plt.xlabel('Task Duration (hours)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 5))
df['Task Preference'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Task Preference Distribution')
plt.ylabel('')
plt.show()

# %%
from collections import Counter
import ast

skills = [skill for sublist in df['Skills'].apply(ast.literal_eval) for skill in sublist]
skill_counts = Counter(skills)

plt.figure(figsize=(12, 6))
sns.barplot(x=list(skill_counts.keys()), y=list(skill_counts.values()))
plt.title('Skill Distribution')
plt.xlabel('Skill')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Assigned Status', data=df, order=['Unassigned', 'Assigned', 'Completed'])
plt.title('Task Assignment Status')
plt.xlabel('Assigned Status')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(8, 5))
df['Feedback'].value_counts().plot(kind='bar')
plt.title('Feedback Distribution')
plt.xlabel('Feedback')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()
